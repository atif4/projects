# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
file = 'https://aegis4048.github.io/downloads/notebooks/sample_data/unconv_MV_v5.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0     1  12.08  2.92  2.80    81.40  1.16  2.31  4165.196191
# 1     2  12.38  3.53  3.22    46.17  0.89  1.88  3561.146205
# 2     3  14.02  2.59  4.01    72.80  0.89  2.72  4284.348574
# 3     4  17.67  6.75  2.63    39.81  1.08  1.88  5098.680869
# 4     5  17.52  4.57  3.18    10.94  1.51  1.90  3406.132832

# %%
def get_plt_scatter(col_id1, col_id2):
    plt.scatter(df[col_id1],df[col_id2],color='red',label='scatter')
    plt.show()
get_plt_scatter('Por', 'Prod')

# %%
df['Por'].shape
# Out:
# (200,)

# %%
X = df['Por'].values.reshape(-1,1) # it used to convert the dimension 
y = df['Prod'].values

# %%
X.shape
# Out:
# (200, 1)

# %%
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X)

# %%
r2 = lr.score(X,y)

# %%
plt.style.use('default')
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(X,pred, color='k', label='Regression model')
ax.scatter(X, y, edgecolor='k', facecolor='red', alpha=0.7, label='Sample data')
ax.scatter(X, pred, edgecolor='k', facecolor='blue', alpha=0.7, label='r2')
ax.set_ylabel('Gas production (Mcf/day)', fontsize=10)
ax.set_xlabel('Porosity (%)', fontsize=10)
ax.text(0.3, 0.1, 'aegis4048.github.io', fontsize=3, ha='center', va='center',transform=ax.transAxes, color='red', alpha=0.2)
ax.legend(facecolor='white', fontsize=8)
ax.set_title('$R^2= %.2f$' % r2, fontsize=10)
fig.tight_layout()

# %% [raw]
# def get_xy_mean_value(c_id1,c_id2):
#     global X, Y, x_mean, y_mean, n
#     X = df[c_id1].values
#     Y = df[c_id2].values
#     x_mean = np.mean(X)
#     y_mean = np.mean(Y)
#     n = len(X)
#     #return X, Y, x_mean, y_mean, n
# get_xy_mean_value('Por','Prod')

# %% [raw]
# def get_Slope_y_intercept_value(xmean,ymean):
#     numer = 0
#     denom = 0
#     global m, c, y_intercept, x
#     for i in range(n):
#         """formule of slope =(x-x')*(y-y')/(x-x')^2"""
#         numer += (X[i] - xmean) * (Y[i] - ymean)
#         denom += (X[i] - xmean) ** 2
#     m = numer/denom
#     print("this is slope:",m)
#     c = ymean - m*xmean
#     print("this is y_intercept:",c)
#     y_intercept = m*xmean + c
#     print("this is value of Y coordinate:",y_intercept)
#     x = (ymean - c)/m
#     print("this is value of X coordinate:",x)
#     #return m,c,y,x
# get_Slope_y_intercept_value(x_mean,y_mean)

# %% [raw]
# def get_plt_scatter(col_id1, col_id2):
#     plt.scatter(df[col_id1],df[col_id2],color='blue',label='scatter')
#     plt.show()
# get_plt_scatter('Por','Prod')

# %% [raw]
# def get_linear_line(xlbl,ylbl,title):
#     x_max = np.max(X)+100
#     x_min = np.min(X)-100
#     #calculatING the line value of x and y
#     #x_max is starting point and x_min is ending point number of items = 1000 or 100 or 50
#     x = np.linspace(x_max, x_min, 1000)
#     y_intercept = m*x + c
#     #this is for line
#     plt.plot(x,y_intercept,color='red', label="RL")
#     plt.scatter(X,Y,color='blue',label='scatter')
#     plt.xlabel(xlbl)
#     plt.ylabel(ylbl)
#     plt.title(title)
#     plt.legend()
#     plt.show()
# get_linear_line("Porosity (%)", "Gas production (Mcf/day)",title="Porosity (%) v/s Gas production (Mcf/day)")

# %% [raw]
# def get_r_square():
#     global X_re,Y_pred
#     #it is array for n_numbers_of_x and dimension is 1
#     X_re = X.reshape((n,1))
#     reg_fit = lr.fit(X_re,Y)
#     Y_pred = lr.predict(X_re)
#     r2_score = lr.score(X_re,Y)
#     return r2_score

# %% [raw]
# get_r_square()

# %% [raw]
# def get_linear_line(xlbl,ylbl,title):
#     x_max = np.max(X)+100
#     x_min = np.min(X)-100
#     #calculatING the line va;ue of x and y
#     #x_max is starting point and x_min is ending point number of items = 1000 or 100 or 50
#     x = np.linspace(x_max, x_min, 1000)
#     y_intercept = m*x + c
#     #this is for line
#     plt.plot(x,y_intercept,color='red', label="RL")
#     plt.scatter(X_re,Y_pred,color='blue',label='scatter')
#     plt.xlabel(xlbl, fontsize=10)
#     plt.ylabel(ylbl,fontsize=10)
#     plt.title(title % r2, fontsize=10)
#     plt.legend()
#     plt.show()
# get_linear_line("Porosity (%)", "Gas production (Mcf/day)",title=('$R^2= %.2f$'))
